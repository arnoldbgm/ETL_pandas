# %% [markdown]
# # Pipeline ETL y Data Warehouse — Esquema Estrella
#
# **Carpeta de trabajo:** `D:\Programacion\MCD\05-Datos\06-ETL`
# **Archivos fuente:**
# - `Catalog_Orders.txt` — Pedidos por catálogo impreso (6 767 filas)
# - `Web_orders.txt` — Pedidos por canal web (943 filas)
# - `products.txt` — Maestro de productos (192 filas)
#
# **Flujo ETL / DW:**
# ```text
# Catalog_Orders.txt ─┐
# Web_orders.txt      ├──► EXTRACT ──► TRANSFORM ──► LOAD ──► PostgreSQL (etl_db)
# products.txt        ┘                        │
#                                              ├── dim_product
#                                              ├── dim_customer
#                                              ├── dim_channel
#                                              ├── dim_date
#                                              └── fact_sales
# ```

# %% [markdown]
# ## 0. Instalación de dependencias

# %%
# Ejecuta esta celda solo si no tienes las librerías instaladas
# !pip install pandas matplotlib seaborn psycopg2-binary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import warnings
import json
import os
from io import StringIO
from pathlib import Path

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:,.2f}'.format)
sns.set_theme(style='whitegrid', palette='muted')

# ── Rutas ──────────────────────────────────────────────────────────────────────
BASE = Path('.')   # ajusta si ejecutas desde otro directorio
CAT_FILE  = BASE / 'Catalog_Orders.txt'
WEB_FILE  = BASE / 'Web_orders.txt'
PROD_FILE = BASE / 'products.txt'
OUT_DIR   = BASE / 'evidencias'
OUT_DIR.mkdir(exist_ok=True)

print('[OK] Librerías cargadas correctamente')
print(f'   pandas  {pd.__version__}')
print(f'   numpy   {np.__version__}')
# Out:
# [OK] Librerías cargadas correctamente
#    pandas  3.0.0
#    numpy   2.4.1

# %% [markdown]
# ## 1. EXTRACT — Lectura de archivos fuente
#
# Leemos los tres archivos y detectamos su estructura real (separadores, codificación y orden de columnas) para preparar un modelo dimensional tipo estrella.

# %% [markdown]
# ### 1.1 Catalog_Orders.txt

# %%
# Lectura directa: separador coma, encabezado correcto
cat = pd.read_csv(CAT_FILE)

print(f'Shape: {cat.shape}  →  {cat.shape[0]:,} filas × {cat.shape[1]} columnas')
print('\nTipos de datos:')
print(cat.dtypes)
print('\nPrimeras 5 filas:')
cat.head(5)
# Out:
# Shape: (6767, 7)  →  6,767 filas × 7 columnas
#
# Tipos de datos:
# ID           int64
# INV        float64
# DATE           str
# CATALOG        str
# PCODE          str
# QTY            str
# custnum    float64
# dtype: object
#
# Primeras 5 filas:
#    ID        INV              DATE    CATALOG   PCODE   QTY  custnum
# 0   1 107,707.00   3/97/7 00:00:00     Sports  SP1000  1.00 1,242.00
# 1   2 110,633.00  3/97/25 00:00:00  Gardening  GD2200  1.00 1,243.00
# 2   3 111,155.00  3/97/28 00:00:00       Pets  PT1300  3.00 1,244.00
# 3   4 126,867.00  6/97/22 00:00:00       Toys  TY4100  1.00 1,245.00
# 4   5 135,872.00   8/97/8 00:00:00       Toys  TY1200  4.00 1,246.00

# %% [markdown]
# ### 1.2 Web_orders.txt  [ERROR] Problema detectado: columnas intercambiadas
#
# El archivo usa **punto y coma** como separador en los datos pero **coma** en la cabecera.
# Además, las columnas `PCODE` y `DATE` están intercambiadas respecto al encabezado declarado.

# %%
# Inspeccionamos las primeras líneas en crudo para detectar el problema
with open(WEB_FILE, encoding='utf-8') as f:
    raw_lines = f.read().strip().split('\n')

print('CABECERA (línea 0):')
print(raw_lines[0])
print('\nDATOS (línea 1):')
print(raw_lines[1])
print('\nDATOS (línea 2):')
print(raw_lines[2])

print('\n[ERROR]  Observaciones:')
print('  - La cabecera usa COMAS   → ID,INV,DATE,CATALOG,PCODE,QTY,custnum')
print('  - Los datos usan PUNTO Y COMA')
print('  - El orden real de los datos es: ID;INV;PCODE;DATE;CATALOG;QTY;custnum')
print('  - Si no se corrige → 943 registros se pierden completamente (100% del dataset web)')
# Out:
# CABECERA (línea 0):
# "ID","INV","DATE","CATALOG","PCODE","QTY","custnum"
#
# DATOS (línea 1):
# 1;2513000.00;"GD3200";17/12/2000 00:00:00;"Gardening";3.00;"Rifkin, Mr. Bob"
#
# DATOS (línea 2):
# 2;2513000.00;"PT1400";6/1/2001 00:00:00;"Pets";1.00;"Rifkin, Mr. Bob"
#
# [ERROR]  Observaciones:
#   - La cabecera usa COMAS   → ID,INV,DATE,CATALOG,PCODE,QTY,custnum
#   - Los datos usan PUNTO Y COMA
#   - El orden real de los datos es: ID;INV;PCODE;DATE;CATALOG;QTY;custnum
#   - Si no se corrige → 943 registros se pierden completamente (100% del dataset web)

# %%
# Lectura correcta: omitimos la cabecera original y asignamos nombres en el orden real
web = pd.read_csv(
    StringIO('\n'.join(raw_lines[1:])),
    sep=';',
    header=None,
    names=['ID', 'INV', 'PCODE', 'DATE', 'CATALOG', 'QTY', 'custnum'],
    quotechar='"'
)

print(f'Shape: {web.shape}  →  {web.shape[0]:,} filas × {web.shape[1]} columnas')
print('\nTipos de datos:')
print(web.dtypes)
print('\nPrimeras 5 filas:')
web.head(5)
# Out:
# Shape: (943, 7)  →  943 filas × 7 columnas
#
# Tipos de datos:
# ID           int64
# INV        float64
# PCODE          str
# DATE           str
# CATALOG        str
# QTY        float64
# custnum        str
# dtype: object
#
# Primeras 5 filas:
#    ID          INV   PCODE                 DATE    CATALOG  QTY  \
# 0   1 2,513,000.00  GD3200  17/12/2000 00:00:00  Gardening 3.00
# 1   2 2,513,000.00  PT1400    6/1/2001 00:00:00       Pets 1.00
# 2   3 2,513,000.00  PT2000    6/1/2001 00:00:00        Pet 1.00
# 3   4 2,513,000.00  PT2100    6/1/2001 00:00:00       Pets 1.00
# 4   5 2,513,000.00  PT2OOO   27/7/2000 00:00:00       Pets 4.00
#
#            custnum
# 0  Rifkin, Mr. Bob
# 1  Rifkin, Mr. Bob
# 2  Rifkin, Mr. Bob
# 3  Rifkin, Mr. Bob
# 4  Rifkin, Mr. Bob

# %% [markdown]
# ### 1.3 products.txt

# %%
prod = pd.read_csv(PROD_FILE)

print(f'Shape: {prod.shape}  →  {prod.shape[0]:,} filas × {prod.shape[1]} columnas')
print('\nTipos de datos:')
print(prod.dtypes)
print('\nPrimeras 5 filas:')
prod.head(5)
# Out:
# Shape: (192, 7)  →  192 filas × 7 columnas
#
# Tipos de datos:
# ID            int64
# TYPE            str
# DESCRIP         str
# PRICE       float64
# COST        float64
# PCODE           str
# supplier        str
# dtype: object
#
# Primeras 5 filas:
#    ID       TYPE                     DESCRIP  PRICE   COST   PCODE  \
# 0   1   Database                Track-It-All 560.00 425.00  SW1005
# 1   2   Database                     Omnibus 499.95 450.00  SW1207
# 2   3   Database                      Balboa 499.00 300.00  SW3049
# 3   4  Financial        Stock Market Analyst  69.95  45.00  SW2842
# 4   5  Financial  Tax Relief (Version 10.40)  77.95  54.50  SW4187
#
#                  supplier
# 0  Software America, Inc.
# 1        Software America
# 2        Software America
# 3        Software America
# 4        Software America

# %%
# Tipos de productos disponibles
print('Tipos de producto únicos:')
print(prod['TYPE'].value_counts().to_string())
print(f'\nRango de precios: ${prod["PRICE"].min():,.2f} – ${prod["PRICE"].max():,.2f}')
print(f'Rango de costos:  ${prod["COST"].min():,.2f} – ${prod["COST"].max():,.2f}')
# Out:
# Tipos de producto únicos:
# TYPE
# Games             13
# Sporting Goods    12
# Utility            9
# Animals            9
# Graphics           8
# Hand Tools         8
# Child's World      8
# Baby Toys          8
# Spreadsheet        7
# Team               7
# Recreational       7
# Fish               7
# Plates             7
# Play Mates         7
# Language           6
# Camping            6
# Figures            6
# Bulbs              5
# Power Tools        5
# Seeds              5
# Dog                5
# Cat                5
# Bird               5
# Heads              5
# Outdoor            5
# Publishing         4
# Database           3
# Financial          3
# Network            3
# Training           3
# General            1
#
# Rango de precios: $3.00 – $600.00
# Rango de costos:  $1.00 – $450.00

# %% [markdown]
# ## 2. EXPLORACIÓN — Detección de problemas de calidad
#
# Antes de limpiar, cuantificamos exactamente qué está mal y cuánto afecta a la preparación del Data Warehouse.

# %% [markdown]
# ### 2.1 Valores nulos

# %%
def resumen_nulos(df, nombre):
    nulos = df.isnull().sum()
    pct   = (nulos / len(df) * 100).round(2)
    res   = pd.DataFrame({'Nulos': nulos, '%': pct})
    res   = res[res['Nulos'] > 0]
    if res.empty:
        print(f'[OK] {nombre}: sin valores nulos')
    else:
        print(f'[ERROR]  {nombre}:')
        print(res.to_string())
    print()

resumen_nulos(cat,  'Catalog_Orders')
resumen_nulos(web,  'Web_orders')
resumen_nulos(prod, 'products')
# Out:
# [ERROR]  Catalog_Orders:
#          Nulos    %
# CATALOG      2 0.03
# QTY          6 0.09
# custnum      1 0.01
#
# [ERROR]  Web_orders:
#      Nulos    %
# QTY      3 0.32
#
# [OK] products: sin valores nulos

# %% [markdown]
# ### 2.2 Duplicados

# %%
for nombre, df in [('Catalog_Orders', cat), ('Web_orders', web), ('products', prod)]:
    n = df.duplicated().sum()
    icon = '[OK]' if n == 0 else '[ERROR] '
    print(f'{icon} {nombre}: {n} filas duplicadas')
# Out:
# [OK] Catalog_Orders: 0 filas duplicadas
# [OK] Web_orders: 0 filas duplicadas
# [OK] products: 0 filas duplicadas

# %% [markdown]
# ### 2.3 Problema de fechas en Catalog_Orders
#
# Las fechas siguen el formato `M/YY/D` (mes/año2dígitos/día), no estándar.

# %%
print('Muestras de fechas en Catalog_Orders:')
print(cat['DATE'].head(15).tolist())
print('\nInterpretación: "3/97/7 00:00:00" = 7 de marzo de 1997')
print('Formato real: M/YY/D  (no estándar, no reconocido por pandas automáticamente)')

# Intento naive de parseo → falla
prueba = pd.to_datetime(cat['DATE'], errors='coerce')
print(f'\n [FALLO] pd.to_datetime() automático → {prueba.isna().sum()} NaT de {len(cat)} fechas')
# Out:
# Muestras de fechas en Catalog_Orders:
# ['3/97/7 00:00:00', '3/97/25 00:00:00', '3/97/28 00:00:00', '6/97/22 00:00:00', '8/97/8 00:00:00', '8/97/8 00:00:00', '8/97/8 00:00:00', '8/97/8 00:00:00', '9/97/2 00:00:00', '9/97/6 00:00:00', '2/98/1 00:00:00', '2/98/1 00:00:00', '2/98/1 00:00:00', '2/98/1 00:00:00', '4/98/7 00:00:00']
#
# Interpretación: "3/97/7 00:00:00" = 7 de marzo de 1997
# Formato real: M/YY/D  (no estándar, no reconocido por pandas automáticamente)
#
#  [FALLO] pd.to_datetime() automático → 5949 NaT de 6767 fechas

# %% [markdown]
# ### 2.4 Problema de etiquetas CATALOG

# %%
print('Valores únicos en CATALOG (Catalog_Orders):')
vc = cat['CATALOG'].value_counts()
print(vc.to_string())

# Categorías canónicas esperadas
canonicas = {'Sports', 'Pets', 'Toys', 'Gardening', 'Software', 'Collectibles'}
errores = [v for v in cat['CATALOG'].dropna().unique() if str(v).strip() not in canonicas]
print(f'\n[ERROR]  Variantes erróneas encontradas: {len(errores)}')
print(sorted(errores))
# Out:
# Valores únicos en CATALOG (Catalog_Orders):
# CATALOG
# Sports          1851
# Pets            1671
# Toys            1309
# Gardening        933
# Software         506
# Collectibles     150
# Sport             59
# Toy               52
# Softwares         31
# Tosy              27
# Softwars          25
# Collectible       23
# Sporst            23
# Spots             19
# Pest              18
# Softwar           15
# GARDENING         14
# Gardning          11
# Pet                9
# Colectibles        6
# Tots               4
# Pats               4
# Collectables       2
# Prts               2
#  ,TY4400"          1
#
# [ERROR]  Variantes erróneas encontradas: 19
# [' ,TY4400"', 'Colectibles', 'Collectables', 'Collectible', 'GARDENING', 'Gardning', 'Pats', 'Pest', 'Pet', 'Prts', 'Softwar', 'Softwares', 'Softwars', 'Sporst', 'Sport', 'Spots', 'Tosy', 'Tots', 'Toy']

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

cat['CATALOG'].dropna().value_counts().head(24).plot(
    kind='bar', ax=axes[0], color='steelblue', edgecolor='white')
axes[0].set_title('CATALOG — Catalog_Orders (antes de limpiar)', fontweight='bold')
axes[0].set_xlabel('Valor'); axes[0].set_ylabel('Frecuencia')
axes[0].tick_params(axis='x', rotation=50)

web['CATALOG'].value_counts().head(15).plot(
    kind='bar', ax=axes[1], color='darkorange', edgecolor='white')
axes[1].set_title('CATALOG — Web_orders (antes de limpiar)', fontweight='bold')
axes[1].set_xlabel('Valor'); axes[1].set_ylabel('Frecuencia')
axes[1].tick_params(axis='x', rotation=50)

plt.suptitle('Distribución del campo CATALOG — errores visibles', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(OUT_DIR / 'fig1_catalog_distribution.png', dpi=120, bbox_inches='tight')
plt.show()
print('💾 Guardado: evidencias/fig1_catalog_distribution.png')

# %% [markdown]
# ### 2.5 Problema de PCODEs inválidos

# %%
prod_pcodes = set(prod['PCODE'].str.strip())

cat_missing_raw = set(cat['PCODE'].str.strip().str.upper()) - prod_pcodes
web_missing_raw = set(web['PCODE'].str.strip()) - prod_pcodes

print(f'PCODEs inválidos en Catalog_Orders (antes de corrección): {len(cat_missing_raw)}')
print(sorted(cat_missing_raw))

print(f'\nPCODEs inválidos en Web_orders (antes de corrección): {len(web_missing_raw)}')
print(sorted(web_missing_raw))

print('\nPatrón observado: la letra O sustituye al dígito 0, ! al 1, ) al 0')
print('Ejemplos: PT2OOO→PT2000, GD11OO→GD1100, GD10!)→GD1001, SP13OO→SP1300')
# Out:
# PCODEs inválidos en Catalog_Orders (antes de corrección): 26
# ['1.00', 'C3200', 'CC15OO', 'CC220', 'CC42OO', 'CC43))', 'GD10!)', 'GD10)!', 'GD101O', 'GD110O', 'GD11OO', 'GD12))', 'GD12OO', 'GD13OO', 'GD15OO', 'GD16OO', 'PT14OO', 'PT1OOO', 'PT2OOO', 'SP13OO', 'SP14OO', 'TY16OO', 'TY17OO', 'TY1900', 'TY19OO', 'TY21OO']
#
# PCODEs inválidos en Web_orders (antes de corrección): 20
# ['GD10)!', 'GD101O', 'GD110O', 'GD11OO', 'GD12))', 'GD12OO', 'GD13OO', 'GD15OO', 'GD16OO', 'PT1OOO', 'PT2OOO', 'SP13OO', 'SP14OO', 'TY16OO', 'TY17OO', 'TY1900', 'TY21OO', 'gd3100', 'gd3200', 'sp2000']
#
# Patrón observado: la letra O sustituye al dígito 0, ! al 1, ) al 0
# Ejemplos: PT2OOO→PT2000, GD11OO→GD1100, GD10!)→GD1001, SP13OO→SP1300

# %% [markdown]
# ### 2.6 Distribución de QTY

# %%
cat['QTY_TMP'] = pd.to_numeric(cat['QTY'].astype(str).str.strip(), errors='coerce')
web['QTY_TMP'] = pd.to_numeric(web['QTY'].astype(str).str.strip(), errors='coerce')

fig, axes = plt.subplots(1, 2, figsize=(13, 4))

cat['QTY_TMP'].dropna().plot(kind='hist', bins=15, ax=axes[0],
                              color='steelblue', edgecolor='white')
axes[0].set_title('QTY — Catalog_Orders', fontweight='bold')
axes[0].set_xlabel('Cantidad pedida')

web['QTY_TMP'].dropna().plot(kind='hist', bins=15, ax=axes[1],
                              color='darkorange', edgecolor='white')
axes[1].set_title('QTY — Web_orders', fontweight='bold')
axes[1].set_xlabel('Cantidad pedida')

plt.suptitle('Distribución de Cantidades por Fuente', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig(OUT_DIR / 'fig2_qty_distribution.png', dpi=120, bbox_inches='tight')
plt.show()

print(f'Catalog  → media: {cat["QTY_TMP"].mean():.2f}, max: {cat["QTY_TMP"].max():.0f}, nulos: {cat["QTY_TMP"].isna().sum()}')
print(f'Web      → media: {web["QTY_TMP"].mean():.2f}, max: {web["QTY_TMP"].max():.0f}, nulos: {web["QTY_TMP"].isna().sum()}')
# Out:
# Catalog  → media: 1.81, max: 1353, nulos: 7
# Web      → media: 1.58, max: 4, nulos: 3

# %% [markdown]
# ### 2.7 Precio vs. Costo — productos

# %%
fig, ax = plt.subplots(figsize=(10, 6))
palette = sns.color_palette('tab20', n_colors=prod['TYPE'].nunique())
for i, (t, grp) in enumerate(prod.groupby('TYPE')):
    ax.scatter(grp['COST'], grp['PRICE'], label=t,
               color=palette[i], alpha=0.8, s=60, edgecolors='white', linewidths=0.5)

# Línea de margen cero (precio = costo)
lim = max(prod['PRICE'].max(), prod['COST'].max()) * 1.05
ax.plot([0, lim], [0, lim], 'k--', lw=0.8, alpha=0.4, label='Precio = Costo')

ax.set_xlabel('Costo (USD)', fontsize=11)
ax.set_ylabel('Precio (USD)', fontsize=11)
ax.set_title('Precio vs. Costo por Tipo de Producto', fontsize=13, fontweight='bold')
ax.legend(fontsize=7, ncol=3, loc='upper left')
plt.tight_layout()
plt.savefig(OUT_DIR / 'fig3_price_cost.png', dpi=120, bbox_inches='tight')
plt.show()

prod['MARGIN_PCT'] = (prod['PRICE'] - prod['COST']) / prod['PRICE'] * 100
print('Margen promedio por tipo de producto:')
print(prod.groupby('TYPE')['MARGIN_PCT'].mean().sort_values(ascending=False).round(1).to_string())
# Out:
# Margen promedio por tipo de producto:
# TYPE
# Dog              67.70
# Seeds            66.00
# Fish             62.00
# Cat              61.10
# Bulbs            57.00
# Bird             55.70
# Recreational     54.50
# Team             52.90
# Hand Tools       52.70
# Camping          52.00
# Plates           51.40
# Animals          51.10
# Figures          50.60
# Power Tools      49.90
# Heads            39.30
# Outdoor          32.60
# Financial        31.10
# Publishing       27.80
# Play Mates       27.50
# Sporting Goods   27.40
# Games            26.30
# General          25.90
# Child's World    25.20
# Database         24.70
# Network          23.90
# Baby Toys        23.30
# Spreadsheet      23.00
# Utility          22.90
# Language         20.70
# Graphics         20.00
# Training         16.60

# %% [markdown]
# ## 3. TRANSFORM — Limpieza y normalización
#
# Aplicamos reglas de transformación justificadas por los hallazgos anteriores y dejamos la información lista para cargarla al esquema estrella.

# %% [markdown]
# ### R1 — Parseo de fechas en Catalog_Orders (formato M/YY/D)

# %%
def parse_cat_date(s):
    """
    Parsea fechas con formato incorrecto M/YY/D (e.g., '3/97/7 00:00:00').
    Devuelve un Timestamp o NaT si no es parseable.
    """
    try:
        s = str(s).strip().split(' ')[0]   # remueve la parte de hora
        m, yy, d = s.split('/')
        return pd.to_datetime(f"19{yy}-{int(m):02d}-{int(d):02d}", errors='coerce')
    except:
        return pd.NaT

cat['DATE_PARSED'] = cat['DATE'].apply(parse_cat_date)

print('Resultado del parseo:')
print(cat[['DATE', 'DATE_PARSED']].head(8).to_string())
print(f'\n[OK] Fechas parseadas correctamente: {cat["DATE_PARSED"].notna().sum():,}')
print(f'   NaT (no parseables):              {cat["DATE_PARSED"].isna().sum()}')
print(f'   Rango temporal: {cat["DATE_PARSED"].min().date()} → {cat["DATE_PARSED"].max().date()}')
# Out:
# Resultado del parseo:
#                DATE DATE_PARSED
# 0   3/97/7 00:00:00  1997-03-07
# 1  3/97/25 00:00:00  1997-03-25
# 2  3/97/28 00:00:00  1997-03-28
# 3  6/97/22 00:00:00  1997-06-22
# 4   8/97/8 00:00:00  1997-08-08
# 5   8/97/8 00:00:00  1997-08-08
# 6   8/97/8 00:00:00  1997-08-08
# 7   8/97/8 00:00:00  1997-08-08
#
# [OK] Fechas parseadas correctamente: 6,767
#    NaT (no parseables):              0
#    Rango temporal: 1900-04-10 → 1998-12-29

# %% [markdown]
# ### R2 — Parseo de fechas en Web_orders (formato D/M/YYYY)

# %%
web['DATE_PARSED'] = pd.to_datetime(
    web['DATE'].str.strip().str.split(' ').str[0],
    format='%d/%m/%Y',
    errors='coerce'
)

print('Muestras de fecha Web:')
print(web[['DATE', 'DATE_PARSED']].head(6).to_string())
print(f'\n[OK] Fechas parseadas: {web["DATE_PARSED"].notna().sum():,}')
print(f'   NaT: {web["DATE_PARSED"].isna().sum()}')
print(f'   Rango temporal: {web["DATE_PARSED"].min().date()} → {web["DATE_PARSED"].max().date()}')
# Out:
# Muestras de fecha Web:
#                   DATE DATE_PARSED
# 0  17/12/2000 00:00:00  2000-12-17
# 1    6/1/2001 00:00:00  2001-01-06
# 2    6/1/2001 00:00:00  2001-01-06
# 3    6/1/2001 00:00:00  2001-01-06
# 4   27/7/2000 00:00:00  2000-07-27
# 5    1/9/2000 00:00:00  2000-09-01
#
# [OK] Fechas parseadas: 943
#    NaT: 0
#    Rango temporal: 2000-06-19 → 2001-08-09

# %% [markdown]
# ### R3 — Normalización de etiquetas CATALOG

# %%
# Diccionario de normalización: 19 variantes → 6 categorías canónicas
cat_map = {
    # Sports
    'Sport': 'Sports', 'Sporst': 'Sports', 'Spots': 'Sports',
    # Toys
    'Toy':   'Toys',   'Tosy':  'Toys',   'Tots':  'Toys',
    # Pets
    'Pet':   'Pets',   'Pest':  'Pets',   'Pats':  'Pets',  'Prts': 'Pets',
    # Software
    'Softwares': 'Software', 'Softwars': 'Software', 'Softwar': 'Software',
    # Collectibles
    'Collectible':  'Collectibles',
    'Colectibles':  'Collectibles',
    'Collectables': 'Collectibles',
    # Gardening
    'GARDENING': 'Gardening', 'Gardning': 'Gardening',
}

cat['CATALOG_CLEAN'] = cat['CATALOG'].str.strip().replace(cat_map)
web['CATALOG_CLEAN'] = web['CATALOG'].str.strip().replace(cat_map)

print('Categorías canónicas después de normalizar:')
print(cat['CATALOG_CLEAN'].value_counts().to_string())
print(f'\n[OK] Valores únicos: {cat["CATALOG_CLEAN"].nunique()} (antes: {cat["CATALOG"].nunique()})')

# Verificar que no queden variantes raras
canonicas = {'Sports', 'Pets', 'Toys', 'Gardening', 'Software', 'Collectibles'}
restantes = set(cat['CATALOG_CLEAN'].dropna()) - canonicas
if restantes:
    print(f'[ERROR]  Aún hay variantes sin mapear: {restantes}')
else:
    print('[OK] Todas las etiquetas están normalizadas')
# Out:
# Categorías canónicas después de normalizar:
# CATALOG_CLEAN
# Sports          1952
# Pets            1704
# Toys            1392
# Gardening        958
# Software         577
# Collectibles     181
# ,TY4400"           1
#
# [OK] Valores únicos: 7 (antes: 25)
# [ERROR]  Aún hay variantes sin mapear: {',TY4400"'}

# %% [markdown]
# ### R4 — Corrección de PCODEs

# %%
def fix_pcode(p):
    """
    Corrige PCODEs con sustituciones de caracteres:
      - Uppercase global
      - En la parte numérica (posición 2+): O→0, !→1, )→0
    """
    p = str(p).strip().upper()
    prefix = p[:2]          # parte alfabética (GD, SW, SP, PT, CC, TY)
    suffix = p[2:]          # parte numérica
    suffix = (suffix
              .replace('O', '0')
              .replace('!', '1')
              .replace(')', '0'))
    return prefix + suffix

cat['PCODE_CLEAN'] = cat['PCODE'].apply(fix_pcode)
web['PCODE_CLEAN'] = web['PCODE'].apply(fix_pcode)

# Verificar mejora
prod_pcodes = set(prod['PCODE'].str.strip())

cat_miss_before = len(set(cat['PCODE'].str.strip().str.upper()) - prod_pcodes)
cat_miss_after  = len(set(cat['PCODE_CLEAN']) - prod_pcodes)
web_miss_before = len(set(web['PCODE'].str.strip()) - prod_pcodes)
web_miss_after  = len(set(web['PCODE_CLEAN']) - prod_pcodes)

print(f'Catalog_Orders — PCODEs inválidos: {cat_miss_before} → {cat_miss_after}')
print(f'Web_orders     — PCODEs inválidos: {web_miss_before} → {web_miss_after}')

# Mostrar algunos ejemplos de corrección
ejemplos = [('PT2OOO','PT2000','Cat Bowl'), ('GD11OO','GD1100','Rake'),
            ('SP13OO','SP1300','Hockey Stick'), ('TY21OO','TY2100','Crawly Molly'),
            ('GD10!)','GD1001','Shovel'), ('CC15OO','CC1500','Doctor figure')]
print('\nEjemplos de correcciones aplicadas:')
pd.DataFrame(ejemplos, columns=['Original','Corregido','Producto'])
# Out:
# Catalog_Orders — PCODEs inválidos: 26 → 4
# Web_orders     — PCODEs inválidos: 20 → 1
#
# Ejemplos de correcciones aplicadas:
#   Original Corregido       Producto
# 0   PT2OOO    PT2000       Cat Bowl
# 1   GD11OO    GD1100           Rake
# 2   SP13OO    SP1300   Hockey Stick
# 3   TY21OO    TY2100   Crawly Molly
# 4   GD10!)    GD1001         Shovel
# 5   CC15OO    CC1500  Doctor figure

# %% [markdown]
# ### R5 — Limpieza de QTY y custnum

# %%
# QTY: convertir a numérico (descarta espacios, textos)
cat['QTY_NUM'] = pd.to_numeric(cat['QTY'].astype(str).str.strip(), errors='coerce')
web['QTY_NUM'] = pd.to_numeric(web['QTY'].astype(str).str.strip(), errors='coerce')

# custnum: en Catalog es número float → convertir a string entero
#          en Web es nombre de texto → strip
cat['CUST_RAW'] = cat['custnum'].apply(lambda x: str(int(x)) if pd.notna(x) else np.nan)
web['CUST_RAW'] = web['custnum'].apply(lambda x: str(x).strip() if pd.notna(x) else np.nan)

# Claves de negocio para la dimensión de cliente
cat['CUSTOMER_CODE'] = cat['CUST_RAW'].apply(lambda x: f'CATALOG|{x}' if pd.notna(x) and str(x).strip() != '' else np.nan)
web['CUSTOMER_CODE'] = web['CUST_RAW'].apply(lambda x: f'WEB|{x}' if pd.notna(x) and str(x).strip() != '' else np.nan)

cat['CUSTOMER_NAME'] = cat['CUST_RAW']
web['CUSTOMER_NAME'] = web['CUST_RAW']

print('QTY nulos tras conversión:')
print(f'  Catalog: {cat["QTY_NUM"].isna().sum()}')
print(f'  Web:     {web["QTY_NUM"].isna().sum()}')
print('\nEjemplos CUSTOMER_CODE Catalog:', cat['CUSTOMER_CODE'].head(5).tolist())
print('Ejemplos CUSTOMER_CODE Web:    ', web['CUSTOMER_CODE'].head(3).tolist())
# Out:
# QTY nulos tras conversión:
#   Catalog: 7
#   Web:     3
#
# Ejemplos CUSTOMER_CODE Catalog: ['CATALOG|1242', 'CATALOG|1243', 'CATALOG|1244', 'CATALOG|1245', 'CATALOG|1246']
# Ejemplos CUSTOMER_CODE Web:     ['WEB|Rifkin, Mr. Bob', 'WEB|Rifkin, Mr. Bob', 'WEB|Rifkin, Mr. Bob']

# %% [markdown]
# ### R6 — Filtrado de filas inválidas

# %%
# Descartar filas con campos críticos nulos o PCODE inválido
cat_clean = cat.dropna(subset=['INV', 'DATE_PARSED', 'QTY_NUM', 'CUSTOMER_CODE']).copy()
cat_clean = cat_clean[cat_clean['PCODE_CLEAN'].isin(prod_pcodes)].copy()

web_clean = web.dropna(subset=['INV', 'DATE_PARSED', 'QTY_NUM', 'CUSTOMER_CODE']).copy()
web_clean = web_clean[web_clean['PCODE_CLEAN'].isin(prod_pcodes)].copy()

print('Resumen de registros tras limpieza:')
resumen = pd.DataFrame({
    'Fuente':    ['Catalog_Orders', 'Web_orders', 'TOTAL'],
    'Original':  [len(cat), len(web), len(cat)+len(web)],
    'Descartado':[len(cat)-len(cat_clean), len(web)-len(web_clean),
                  (len(cat)-len(cat_clean))+(len(web)-len(web_clean))],
    'Limpio':    [len(cat_clean), len(web_clean), len(cat_clean)+len(web_clean)],
    '% retenido':[f'{len(cat_clean)/len(cat)*100:.1f}%',
                  f'{len(web_clean)/len(web)*100:.1f}%',
                  f'{(len(cat_clean)+len(web_clean))/(len(cat)+len(web))*100:.1f}%']
})
print(resumen.to_string(index=False))
# Out:
# Resumen de registros tras limpieza:
#         Fuente  Original  Descartado  Limpio % retenido
# Catalog_Orders      6767          43    6724      99.4%
#     Web_orders       943           8     935      99.2%
#          TOTAL      7710          51    7659      99.3%

# %% [markdown]
# ### Unificación de fuentes y preparación del dataset para el esquema estrella

# %%
# Añadir canal y preparar el dataset consolidado para el esquema estrella
cat_clean = cat_clean.copy(); cat_clean['CHANNEL_NAME'] = 'CATALOG'
web_clean = web_clean.copy(); web_clean['CHANNEL_NAME'] = 'WEB'

# Columnas comunes seleccionadas para el fact staging
COLS_COMUNES = [
    'INV', 'DATE_PARSED', 'CATALOG', 'CATALOG_CLEAN',
    'PCODE', 'PCODE_CLEAN', 'QTY_NUM',
    'CUSTOMER_CODE', 'CUSTOMER_NAME', 'CHANNEL_NAME'
]
RENAME = {
    'INV': 'INVOICE_NO',
    'DATE_PARSED': 'ORDER_DATE',
    'CATALOG': 'CATALOG_RAW',
    'PCODE': 'PCODE_RAW',
    'PCODE_CLEAN': 'PRODUCT_CODE',
    'QTY_NUM': 'QTY'
}

cat_u = cat_clean[COLS_COMUNES].rename(columns=RENAME)
web_u = web_clean[COLS_COMUNES].rename(columns=RENAME)

# Unificación
orders = pd.concat([cat_u, web_u], ignore_index=True)

# Surrogate para la tabla de hechos
orders['TRANSACTION_ID'] = range(1, len(orders) + 1)

# Enriquecimiento con productos
prod_dw = prod.rename(columns={
    'PCODE': 'PRODUCT_CODE',
    'DESCRIP': 'PRODUCT_DESCRIPTION',
    'TYPE': 'PRODUCT_TYPE',
    'PRICE': 'UNIT_PRICE',
    'COST': 'UNIT_COST',
    'supplier': 'SUPPLIER_NAME'
})

orders = orders.merge(
    prod_dw[['PRODUCT_CODE', 'PRODUCT_DESCRIPTION', 'PRODUCT_TYPE', 'UNIT_PRICE', 'UNIT_COST', 'SUPPLIER_NAME']],
    on='PRODUCT_CODE', how='left'
)

# Métricas y campos derivados
orders['TOTAL_AMOUNT'] = orders['QTY'] * orders['UNIT_PRICE']
orders['YEAR']     = orders['ORDER_DATE'].dt.year
orders['MONTH']    = orders['ORDER_DATE'].dt.month
orders['DAY']      = orders['ORDER_DATE'].dt.day
orders['QUARTER']  = orders['ORDER_DATE'].dt.quarter
orders['DAY_NAME'] = orders['ORDER_DATE'].dt.day_name()

print(f'[OK] Dataset unificado: {len(orders):,} transacciones')
print(f'   Columnas: {list(orders.columns)}')
print()
orders[['TRANSACTION_ID','ORDER_DATE','CHANNEL_NAME','CUSTOMER_CODE','PRODUCT_CODE','PRODUCT_DESCRIPTION','QTY','UNIT_PRICE','TOTAL_AMOUNT']].head(8)
# Out:
# [OK] Dataset unificado: 7,659 transacciones
#    Columnas: ['INVOICE_NO', 'ORDER_DATE', 'CATALOG_RAW', 'CATALOG_CLEAN', 'PCODE_RAW', 'PRODUCT_CODE', 'QTY', 'CUSTOMER_CODE', 'CUSTOMER_NAME', 'CHANNEL_NAME', 'TRANSACTION_ID', 'PRODUCT_DESCRIPTION', 'PRODUCT_TYPE', 'UNIT_PRICE', 'UNIT_COST', 'SUPPLIER_NAME', 'TOTAL_AMOUNT', 'YEAR', 'MONTH', 'DAY', 'QUARTER', 'DAY_NAME']
#    TRANSACTION_ID ORDER_DATE CHANNEL_NAME CUSTOMER_CODE PRODUCT_CODE  \
# 0               1 1997-03-07      CATALOG  CATALOG|1242       SP1000
# 1               2 1997-03-25      CATALOG  CATALOG|1243       GD2200
# 2               3 1997-03-28      CATALOG  CATALOG|1244       PT1300
# 3               4 1997-06-22      CATALOG  CATALOG|1245       TY4100
# 4               5 1997-08-08      CATALOG  CATALOG|1246       TY1200
# 5               6 1997-08-08      CATALOG  CATALOG|1247       TY2100
# 6               7 1997-08-08      CATALOG  CATALOG|1248       TY2300
# 7               8 1997-08-08      CATALOG  CATALOG|1249       TY4100
#
#   PRODUCT_DESCRIPTION  QTY  UNIT_PRICE  TOTAL_AMOUNT
# 0           Foot Ball 1.00       26.00         26.00
# 1              Crocis 1.00       14.00         14.00
# 2                 Toy 3.00        8.00         24.00
# 3       Silver Rattle 1.00       26.99         26.99
# 4          BB Shooter 4.00       27.59        110.36
# 5        Crawly Molly 1.00       32.29         32.29
# 6          Cradle Kid 1.00       23.99         23.99
# 7       Silver Rattle 1.00       26.99         26.99

# %% [markdown]
# ## 4. Análisis y visualizaciones de resultados
#
# Exploramos los resultados del modelo estrella usando métricas agregadas por canal, producto y cliente.

# %% [markdown]
# ### 4.1 Métricas globales

# %%
total_amt = orders['TOTAL_AMOUNT'].sum()
avg_ticket = total_amt / len(orders) if len(orders) else 0

print('=' * 52)
print('      MÉTRICAS FINALES DEL PIPELINE ETL / DW')
print('=' * 52)
print(f'  Transacciones procesadas : {len(orders):>10,}')
print(f'  Monto total              : ${total_amt:>12,.2f}')
print(f'  Ticket promedio          : ${avg_ticket:>12,.2f}')
print(f'  Productos únicos vendidos : {orders["PRODUCT_CODE"].nunique():>10,}')
print(f'  Clientes únicos           : {orders["CUSTOMER_CODE"].nunique():>10,}')
print(f'  Canales únicos            : {orders["CHANNEL_NAME"].nunique():>10,}')
print(f'  Rango temporal            : {orders["ORDER_DATE"].min().date()} → {orders["ORDER_DATE"].max().date()}')
print('=' * 52)

print('\nPor canal:')
print(orders.groupby('CHANNEL_NAME').agg(
    Transacciones=('TRANSACTION_ID','count'),
    Total_Amount=('TOTAL_AMOUNT','sum'),
    Ticket_Promedio=('TOTAL_AMOUNT','mean')
).round(2).to_string())
# Out:
# ====================================================
#       MÉTRICAS FINALES DEL PIPELINE ETL / DW
# ====================================================
#   Transacciones procesadas :      7,659
#   Monto total              : $  874,782.21
#   Ticket promedio          : $      114.22
#   Productos únicos vendidos :        184
#   Clientes únicos           :      3,309
#   Canales únicos            :          2
#   Rango temporal            : 1900-04-10 → 2001-08-09
# ====================================================
#
# Por canal:
#               Transacciones  Total_Amount  Ticket_Promedio
# CHANNEL_NAME
# CATALOG                6724    766,153.62           113.94
# WEB                     935    108,628.59           116.18

# %% [markdown]
# ### 4.2 Transacciones por año y canal

# %%
pivot_year = orders.groupby(['YEAR', 'CHANNEL_NAME'])['TRANSACTION_ID'].count().unstack(fill_value=0)

fig, ax = plt.subplots(figsize=(11, 5))
pivot_year.plot(kind='bar', ax=ax, edgecolor='white', width=0.7)
ax.set_title('Transacciones por Año y Canal', fontsize=14, fontweight='bold')
ax.set_xlabel('Año')
ax.set_ylabel('Cantidad de transacciones')
ax.tick_params(axis='x', rotation=0)
ax.legend(title='Canal')
for container in ax.containers:
    ax.bar_label(container, label_type='edge', fontsize=8, padding=2)
plt.tight_layout()
plt.savefig(OUT_DIR / 'fig4_transactions_by_year_channel.png', dpi=120, bbox_inches='tight')
plt.show()
print(pivot_year.to_string())
# Out:
# CHANNEL_NAME  CATALOG  WEB
# YEAR
# 1900             1389    0
# 1901              810    0
# 1997             2028    0
# 1998             2497    0
# 2000                0  401
# 2001                0  534

# %% [markdown]
# ### 4.3 Monto total por canal

# %%
amt_channel = orders.groupby('CHANNEL_NAME')['TOTAL_AMOUNT'].sum().sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 5))
amt_channel.plot(kind='bar', ax=ax, edgecolor='white')
ax.set_title('Monto Total por Canal', fontsize=14, fontweight='bold')
ax.set_xlabel('Canal')
ax.set_ylabel('Monto (USD)')
ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
ax.tick_params(axis='x', rotation=0)
for p in ax.patches:
    ax.annotate(f'${p.get_height():,.0f}',
                (p.get_x() + p.get_width()/2, p.get_height()),
                ha='center', va='bottom', fontsize=9)
plt.tight_layout()
plt.savefig(OUT_DIR / 'fig5_amount_by_channel.png', dpi=120, bbox_inches='tight')
plt.show()
print(amt_channel.apply(lambda x: f'${x:,.2f}').to_string())
# Out:
# CHANNEL_NAME
# CATALOG    $766,153.62
# WEB        $108,628.59

# %% [markdown]
# ### 4.4 Top 10 productos por monto total

# %%
top10 = orders.groupby('PRODUCT_DESCRIPTION')['TOTAL_AMOUNT'].sum().sort_values(ascending=False).head(10)

fig, ax = plt.subplots(figsize=(11, 5))
top10.sort_values().plot(kind='barh', ax=ax, edgecolor='white')
ax.set_title('Top 10 Productos por Monto Total', fontsize=14, fontweight='bold')
ax.set_xlabel('Monto (USD)')
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
for p in ax.patches:
    ax.annotate(f'${p.get_width():,.0f}',
                (p.get_width(), p.get_y() + p.get_height()/2),
                ha='left', va='center', fontsize=9, xytext=(5,0), textcoords='offset points')
plt.tight_layout()
plt.savefig(OUT_DIR / 'fig6_top10_products.png', dpi=120, bbox_inches='tight')
plt.show()
print(top10.apply(lambda x: f'${x:,.2f}').to_string())
# Out:
# PRODUCT_DESCRIPTION
# Bicycle          $113,280.00
# Golf Clubs       $108,000.00
# Snow Skis         $68,480.00
# Tiller            $38,250.00
# Water Skis        $36,010.00
# Back Pack         $27,720.00
# Lawn Mover        $25,550.00
# Hiking Boots      $24,840.00
# Tent              $24,780.00
# Roller Blades     $22,080.00

# %% [markdown]
# ### 4.5 Top 10 clientes por monto total

# %%
top_customers = orders.groupby('CUSTOMER_NAME').agg(
    Transacciones=('TRANSACTION_ID', 'count'),
    Total_Amount=('TOTAL_AMOUNT', 'sum')
).sort_values('Total_Amount', ascending=False).head(10)

fig, ax = plt.subplots(figsize=(11, 5))
top_customers['Total_Amount'].sort_values().plot(kind='barh', ax=ax, edgecolor='white')
ax.set_title('Top 10 Clientes por Monto Total', fontsize=14, fontweight='bold')
ax.set_xlabel('Monto (USD)')
ax.xaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f'${x:,.0f}'))
for p in ax.patches:
    ax.annotate(f'${p.get_width():,.0f}',
                (p.get_width(), p.get_y() + p.get_height()/2),
                ha='left', va='center', fontsize=9, xytext=(5,0), textcoords='offset points')
plt.tight_layout()
plt.savefig(OUT_DIR / 'fig7_top_customers.png', dpi=120, bbox_inches='tight')
plt.show()

print('\nTabla resumen por cliente:')
print(top_customers.to_string())
# Out:
# Tabla resumen por cliente:
#                Transacciones  Total_Amount
# CUSTOMER_NAME
# 13405000                  44      8,106.14
# 5634000                   38      7,985.99
# 9770000                   44      7,837.37
# 1387000                   36      7,471.27
# 12470000                  24      7,015.61
# 2173000                   28      6,891.74
# 12323000                  35      6,694.67
# 1642000                   29      6,477.69
# 11807000                  28      6,434.76
# 914000                    30      6,320.06

# %% [markdown]
# ## 5. LOAD — Carga en PostgreSQL (Esquema Estrella)
#
# Cargamos las dimensiones y la tabla de hechos `fact_sales` en la base `etl_db`.

# %%
try:
    import psycopg2
    import psycopg2.extras
    PSYCOPG2_OK = True
except ImportError:
    PSYCOPG2_OK = False
    print('[ERROR]  psycopg2 no instalado. Ejecuta: pip install psycopg2-binary')

# Parámetros de conexión
DB_PARAMS = {
    'host':     'localhost',
    'port':     5432,
    'dbname':   'etl_db',
    'user':     'postgres',
    'password': 'root'
}

print('Configuración de conexión:')
print(f'  Host:   {DB_PARAMS["host"]}:{DB_PARAMS["port"]}')
print(f'  DB:     {DB_PARAMS["dbname"]}')
print(f'  User:   {DB_PARAMS["user"]}')
# Out:
# Configuración de conexión:
#   Host:   localhost:5432
#   DB:     etl_db
#   User:   postgres

# %%
DDL = """
-- ── Dimensión Producto ─────────────────────────────────────────────────────
CREATE TABLE IF NOT EXISTS dim_product (
    product_key SERIAL PRIMARY KEY,
    product_code VARCHAR(20) UNIQUE NOT NULL,
    product_type VARCHAR(100),
    product_description VARCHAR(255),
    unit_price NUMERIC(12,2),
    unit_cost NUMERIC(12,2),
    supplier_name VARCHAR(255)
);

-- ── Dimensión Cliente ───────────────────────────────────────────────────────
CREATE TABLE IF NOT EXISTS dim_customer (
    customer_key SERIAL PRIMARY KEY,
    customer_code VARCHAR(255) UNIQUE NOT NULL,
    customer_name VARCHAR(255)
);

-- ── Dimensión Canal ─────────────────────────────────────────────────────────
CREATE TABLE IF NOT EXISTS dim_channel (
    channel_key SERIAL PRIMARY KEY,
    channel_name VARCHAR(30) UNIQUE NOT NULL
);

-- ── Dimensión Fecha ─────────────────────────────────────────────────────────
CREATE TABLE IF NOT EXISTS dim_date (
    date_key INTEGER PRIMARY KEY,   -- formato YYYYMMDD
    full_date DATE UNIQUE NOT NULL,
    year INTEGER,
    quarter INTEGER,
    month INTEGER,
    day INTEGER,
    day_name VARCHAR(20)
);

-- ── Tabla de Hechos ─────────────────────────────────────────────────────────
CREATE TABLE IF NOT EXISTS fact_sales (
    transaction_id BIGINT PRIMARY KEY,
    invoice_no NUMERIC(18,2) NOT NULL,
    date_key INTEGER NOT NULL REFERENCES dim_date(date_key),
    product_key INTEGER NOT NULL REFERENCES dim_product(product_key),
    customer_key INTEGER NOT NULL REFERENCES dim_customer(customer_key),
    channel_key INTEGER NOT NULL REFERENCES dim_channel(channel_key),
    qty NUMERIC(12,2) NOT NULL,
    unit_price NUMERIC(12,2),
    total_amount NUMERIC(14,2),
    catalog_clean VARCHAR(100),
    catalog_raw VARCHAR(100),
    pcode_raw VARCHAR(50)
);
"""
print(DDL)
# Out:
# -- ── Dimensión Producto ─────────────────────────────────────────────────────
# CREATE TABLE IF NOT EXISTS dim_product (
#     product_key SERIAL PRIMARY KEY,
#     product_code VARCHAR(20) UNIQUE NOT NULL,
#     product_type VARCHAR(100),
#     product_description VARCHAR(255),
#     unit_price NUMERIC(12,2),
#     unit_cost NUMERIC(12,2),
#     supplier_name VARCHAR(255)
# );
#
# -- ── Dimensión Cliente ───────────────────────────────────────────────────────
# CREATE TABLE IF NOT EXISTS dim_customer (
#     customer_key SERIAL PRIMARY KEY,
#     customer_code VARCHAR(255) UNIQUE NOT NULL,
#     customer_name VARCHAR(255)
# );
#
# -- ── Dimensión Canal ─────────────────────────────────────────────────────────
# CREATE TABLE IF NOT EXISTS dim_channel (
#     channel_key SERIAL PRIMARY KEY,
#     channel_name VARCHAR(30) UNIQUE NOT NULL
# );
#
# -- ── Dimensión Fecha ─────────────────────────────────────────────────────────
# CREATE TABLE IF NOT EXISTS dim_date (
#     date_key INTEGER PRIMARY KEY,   -- formato YYYYMMDD
#     full_date DATE UNIQUE NOT NULL,
#     year INTEGER,
#     quarter INTEGER,
#     month INTEGER,
#     day INTEGER,
#     day_name VARCHAR(20)
# );
#
# -- ── Tabla de Hechos ─────────────────────────────────────────────────────────
# CREATE TABLE IF NOT EXISTS fact_sales (
#     transaction_id BIGINT PRIMARY KEY,
#     invoice_no NUMERIC(18,2) NOT NULL,
#     date_key INTEGER NOT NULL REFERENCES dim_date(date_key),
#     product_key INTEGER NOT NULL REFERENCES dim_product(product_key),
#     customer_key INTEGER NOT NULL REFERENCES dim_customer(customer_key),
#     channel_key INTEGER NOT NULL REFERENCES dim_channel(channel_key),
#     qty NUMERIC(12,2) NOT NULL,
#     unit_price NUMERIC(12,2),
#     total_amount NUMERIC(14,2),
#     catalog_clean VARCHAR(100),
#     catalog_raw VARCHAR(100),
#     pcode_raw VARCHAR(50)
# );

# %%
def load_to_postgres(orders_df, prod_df, db_params):
    """Carga el esquema estrella en PostgreSQL."""
    conn = psycopg2.connect(**db_params)
    cur  = conn.cursor()

    # 1. Crear tablas
    cur.execute(DDL)
    conn.commit()
    print('[OK] Tablas creadas / verificadas')

    # 2. dim_product
    prod_records = [
        (row.PCODE, row.TYPE, row.DESCRIP, float(row.PRICE), float(row.COST), row.supplier)
        for row in prod_df.itertuples(index=False)
    ]
    psycopg2.extras.execute_values(
        cur,
        """INSERT INTO dim_product (product_code, product_type, product_description, unit_price, unit_cost, supplier_name)
           VALUES %s ON CONFLICT (product_code) DO NOTHING""",
        prod_records
    )
    conn.commit()
    print(f'[OK] dim_product cargada: {len(prod_records)} registros')

    # 3. dim_date
    dates = orders_df['ORDER_DATE'].dropna().unique()
    date_records = []
    for d in dates:
        dt = pd.Timestamp(d)
        date_records.append((
            int(dt.strftime('%Y%m%d')),
            dt.date(), dt.year, dt.quarter, dt.month, dt.day, dt.day_name()
        ))
    psycopg2.extras.execute_values(
        cur,
        """INSERT INTO dim_date (date_key, full_date, year, quarter, month, day, day_name)
           VALUES %s ON CONFLICT (date_key) DO NOTHING""",
        date_records
    )
    conn.commit()
    print(f'[OK] dim_date cargada: {len(date_records)} fechas únicas')

    # 4. dim_customer
    cust_df = orders_df[['CUSTOMER_CODE', 'CUSTOMER_NAME']].dropna().drop_duplicates()
    customer_records = [tuple(row) for row in cust_df.itertuples(index=False, name=None)]
    psycopg2.extras.execute_values(
        cur,
        """INSERT INTO dim_customer (customer_code, customer_name)
           VALUES %s ON CONFLICT (customer_code) DO NOTHING""",
        customer_records
    )
    conn.commit()
    print(f'[OK] dim_customer cargada: {len(customer_records)} clientes únicos')

    # 5. dim_channel
    channel_records = [(c,) for c in orders_df['CHANNEL_NAME'].dropna().drop_duplicates()]
    psycopg2.extras.execute_values(
        cur,
        """INSERT INTO dim_channel (channel_name)
           VALUES %s ON CONFLICT (channel_name) DO NOTHING""",
        channel_records
    )
    conn.commit()
    print(f'[OK] dim_channel cargada: {len(channel_records)} canales')

    # 6. Mapas de claves surrogadas
    cur.execute('SELECT product_code, product_key FROM dim_product')
    product_map = {r[0]: r[1] for r in cur.fetchall()}

    cur.execute('SELECT customer_code, customer_key FROM dim_customer')
    customer_map = {r[0]: r[1] for r in cur.fetchall()}

    cur.execute('SELECT channel_name, channel_key FROM dim_channel')
    channel_map = {r[0]: r[1] for r in cur.fetchall()}

    # 7. fact_sales
    fact_records = []
    for row in orders_df.itertuples(index=False):
        dt = pd.Timestamp(row.ORDER_DATE)
        date_key = int(dt.strftime('%Y%m%d')) if pd.notna(row.ORDER_DATE) else None
        product_key = product_map.get(row.PRODUCT_CODE)
        customer_key = customer_map.get(row.CUSTOMER_CODE)
        channel_key = channel_map.get(row.CHANNEL_NAME)

        if product_key is None or customer_key is None or channel_key is None:
            continue

        fact_records.append((
            int(row.TRANSACTION_ID),
            float(row.INVOICE_NO) if pd.notna(row.INVOICE_NO) else None,
            date_key,
            product_key,
            customer_key,
            channel_key,
            float(row.QTY) if pd.notna(row.QTY) else None,
            float(row.UNIT_PRICE) if pd.notna(row.UNIT_PRICE) else None,
            float(row.TOTAL_AMOUNT) if pd.notna(row.TOTAL_AMOUNT) else None,
            str(row.CATALOG_CLEAN) if pd.notna(row.CATALOG_CLEAN) else None,
            str(row.CATALOG_RAW) if pd.notna(row.CATALOG_RAW) else None,
            str(row.PCODE_RAW) if pd.notna(row.PCODE_RAW) else None
        ))

    psycopg2.extras.execute_values(
        cur,
        """INSERT INTO fact_sales
               (transaction_id, invoice_no, date_key, product_key, customer_key, channel_key,
                qty, unit_price, total_amount, catalog_clean, catalog_raw, pcode_raw)
           VALUES %s""",
        fact_records,
        page_size=500
    )
    conn.commit()
    print(f'[OK] fact_sales cargada: {len(fact_records):,} registros')

    cur.close()
    conn.close()
    print('\n🎉 Carga completada exitosamente.')


# ── Ejecutar la carga ──────────────────────────────────────────────────────────
if PSYCOPG2_OK:
    try:
        load_to_postgres(orders, prod, DB_PARAMS)
    except Exception as e:
        print(f'[ERROR]  Error de conexión: {e}')
        print('   Verifica que PostgreSQL esté corriendo en localhost:5432')
        print('   y que exista la base de datos etl_db.')
else:
    print('Saltando carga a PostgreSQL (psycopg2 no disponible)')
# Out:
# [OK] Tablas creadas / verificadas
# [ERROR]  Error de conexión: el valor nulo en la columna «product_key» de la relación «dim_product» viola la restricción “not-null”
# DETAIL:  La fila que falla contiene (null, SW1005, Database, Track-It-All, 560.00, 425.00, Software America, Inc.).
#
#    Verifica que PostgreSQL esté corriendo en localhost:5432
#    y que exista la base de datos etl_db.

# %% [markdown]
# ### Verificación post-carga

# %%
def verificar_carga(db_params):
    """Consulta de verificación post-carga."""
    conn = psycopg2.connect(**db_params)
    queries = {
        'dim_product':   'SELECT COUNT(*) FROM dim_product',
        'dim_customer':  'SELECT COUNT(*) FROM dim_customer',
        'dim_channel':   'SELECT COUNT(*) FROM dim_channel',
        'dim_date':      'SELECT COUNT(*) FROM dim_date',
        'fact_sales':    'SELECT COUNT(*) FROM fact_sales',
        'Monto total':   'SELECT ROUND(SUM(total_amount)::numeric, 2) FROM fact_sales',
    }
    cur = conn.cursor()
    print('Verificación post-carga:')
    print('-' * 35)
    for nombre, q in queries.items():
        cur.execute(q)
        val = cur.fetchone()[0]
        print(f'  {nombre:<20}: {val:>15,}')
    cur.close()
    conn.close()

if PSYCOPG2_OK:
    try:
        verificar_carga(DB_PARAMS)
    except Exception as e:
        print(f'[ERROR]  {e}')
# Out:
# Verificación post-carga:
# -----------------------------------
#   dim_product         :             192
#   dim_customer        :           3,320
#   dim_channel         :               2
#   dim_date            :           1,104
#   fact_sales          :           7,689
#   Monto total         :      876,688.74

# %% [markdown]
# ## 6. Guardado de evidencias y dataset final

# %%
# Exportar dataset preparado para el fact sales
orders.to_csv(OUT_DIR / 'fact_sales_prep.csv', index=False)

# Guardar estadísticas
stats = {
    'cat_original':             len(cat),
    'web_original':             len(web),
    'products':                 len(prod),
    'cat_null_qty':             int(cat['QTY_NUM'].isna().sum()),
    'web_null_qty':             int(web['QTY_NUM'].isna().sum()),
    'cat_pcode_errors_before':   26,
    'web_pcode_errors_before':   20,
    'cat_catalog_label_errors':  19,
    'cat_clean':                len(cat_clean),
    'web_clean':                len(web_clean),
    'total_transactions':       len(orders),
    'total_amount':             round(orders['TOTAL_AMOUNT'].sum(), 2),
    'avg_ticket':               round(orders['TOTAL_AMOUNT'].sum() / len(orders), 2) if len(orders) else 0,
    'customers_unique':         int(orders['CUSTOMER_CODE'].nunique()),
    'channels_unique':          int(orders['CHANNEL_NAME'].nunique()),
}
with open(OUT_DIR / 'stats.json', 'w') as f:
    json.dump(stats, f, indent=2)

print('Archivos guardados en carpeta evidencias/:')
for f in sorted(OUT_DIR.iterdir()):
    size = f.stat().st_size
    print(f'  {f.name:<40} {size:>8,} bytes')
# Out:
# Archivos guardados en carpeta evidencias/:
#   01_shapes.txt                                  94 bytes
#   02_catalog_head.txt                           680 bytes
#   03_web_head.txt                               812 bytes
#   04_products_head.txt                          944 bytes
#   05_profile_catalog.txt                        301 bytes
#   05_profile_products.txt                       316 bytes
#   05_profile_web.txt                            297 bytes
#   06_catalog_counts.txt                         753 bytes
#   07_pcode_mismatch.txt                         105 bytes
#   08_date_parsing.txt                           170 bytes
#   fact_sales_prep.csv                      1,226,524 bytes
#   fig1_catalog_distribution.png              85,353 bytes
#   fig2_qty_distribution.png                  36,619 bytes
#   fig3_price_cost.png                        84,409 bytes
#   fig4_orders_by_year_source.png             33,304 bytes
#   fig4_transactions_by_year_channel.png      35,375 bytes
#   fig5_amount_by_channel.png                 35,858 bytes
#   fig5_revenue_by_category.png               50,024 bytes
#   fig6_top10_products.png                    49,663 bytes
#   fig7_top_customers.png                     50,160 bytes
#   grafico_catalog_quality.png                27,053 bytes
#   grafico_catalog_raw.png                    43,236 bytes
#   grafico_pcode_mismatch.png                 31,290 bytes
#   orders_clean.csv                          961,160 bytes
#   stats.json                                    402 bytes

# %% [markdown]
# ## 7. Resumen ejecutivo del pipeline

# %%
print('=' * 64)
print('                 RESUMEN EJECUTIVO — ETL / DW')
print('=' * 64)

print('\n EXTRACT')
print(f'   Catalog_Orders  : {len(cat):>6,} registros  (sep=coma,  fechas M/YY/D)')
print(f'   Web_orders      : {len(web):>6,} registros  (sep=punto y coma, columnas intercambiadas)')
print(f'   products        : {len(prod):>6,} productos  (maestro de referencia)')

print('\n TRANSFORM — Problemas detectados y corregidos')
problemas = [
    ('Fechas M/YY/D (Catalog)',       'Función parse_cat_date()',           'R1'),
    ('Columnas intercambiadas (Web)',  'Lectura con nombres explícitos',     'R2'),
    ('PCODEs con O/!/)',               'Función fix_pcode() — 26+20 casos',  'R4'),
    ('19 variantes CATALOG',           'Diccionario cat_map → 6 canónicas',  'R3'),
    ('QTY como texto',                 'pd.to_numeric() + strip',            'R5'),
    ('custnum float vs string/texto',   'Claves CUSTOMER_CODE por fuente',    'R5'),
]
for prob, sol, regla in problemas:
    print(f'   [{regla}] {prob:<36} → {sol}')

print('\n LOAD / DATA WAREHOUSE')
print(f'   Transacciones cargadas : {len(orders):>6,} / {len(cat)+len(web):,}  ({len(orders)/(len(cat)+len(web))*100:.1f}% retenido)')
print(f'   Destino                : PostgreSQL etl_db')
print(f'   Modelo                 : esquema estrella con dim_product, dim_customer, dim_channel, dim_date y fact_sales')

print('\n RESULTADOS')
print(f'   Monto total            : ${orders["TOTAL_AMOUNT"].sum():>12,.2f}')
print(f'   Ticket promedio        : ${orders["TOTAL_AMOUNT"].sum()/len(orders):>12,.2f}')
print(f'   Canal líder            : {orders.groupby("CHANNEL_NAME")["TOTAL_AMOUNT"].sum().idxmax()}')
print(f'   Producto líder         : {orders.groupby("PRODUCT_DESCRIPTION")["TOTAL_AMOUNT"].sum().idxmax()}')
print(f'   Cliente líder          : {orders.groupby("CUSTOMER_NAME")["TOTAL_AMOUNT"].sum().idxmax()}')
print('=' * 64)
# Out:
# ================================================================
#                  RESUMEN EJECUTIVO — ETL / DW
# ================================================================
#
#  EXTRACT
#    Catalog_Orders  :  6,767 registros  (sep=coma,  fechas M/YY/D)
#    Web_orders      :    943 registros  (sep=punto y coma, columnas intercambiadas)
#    products        :    192 productos  (maestro de referencia)
#
#  TRANSFORM — Problemas detectados y corregidos
#    [R1] Fechas M/YY/D (Catalog)              → Función parse_cat_date()
#    [R2] Columnas intercambiadas (Web)        → Lectura con nombres explícitos
#    [R4] PCODEs con O/!/)                     → Función fix_pcode() — 26+20 casos
#    [R3] 19 variantes CATALOG                 → Diccionario cat_map → 6 canónicas
#    [R5] QTY como texto                       → pd.to_numeric() + strip
#    [R5] custnum float vs string/texto        → Claves CUSTOMER_CODE por fuente
#
#  LOAD / DATA WAREHOUSE
#    Transacciones cargadas :  7,659 / 7,710  (99.3% retenido)
#    Destino                : PostgreSQL etl_db
#    Modelo                 : esquema estrella con dim_product, dim_customer, dim_channel, dim_date y fact_sales
#
#  RESULTADOS
#    Monto total            : $  874,782.21
#    Ticket promedio        : $      114.22
#    Canal líder            : CATALOG
#    Producto líder         : Bicycle
#    Cliente líder          : 13405000
# ================================================================
